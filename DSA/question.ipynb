# %% [markdown]
# t = ("a", "b", "c", "d")

# %%
t= ("a", "b", "c", "d")
l = ["Apple", "Dog", "Ball", "Cat", ]
output = {"a":"Apple", "b": "Ball", "c": "Cat", "d": "Dog"}

# %%
output1=dict()
for j in l:
    for i in t:
        output1[i]=output1[j]
        break
    break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       2 for j in l:
#       3     for i in t:
# ----> 4         output1[i]=output1[j]
#       5         break
#       6     break
#
# KeyError: 'Apple'
